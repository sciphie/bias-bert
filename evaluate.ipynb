# %%
from glob import glob 
import pandas as pd 
import pickle as p

from util import identify_spec, identify_model_id, identify_task

# %%
print( "res_models/models/IMDB_distbase_N_pro/e20do5_epoch18/"[45:])
# Out:
# epoch18/

# %%
acc_df = pd.DataFrame({ "batch":[], "accuracy":[], "recall":[], "precision":[], "f1":[], "spec":[], "model_id":[], "task":[]})

for dlem in glob("res_models/models/*/*['epoch']*/"):
    print(dlem)
    spec =  identify_spec(dlem)
    model_id = identify_model_id(dlem)
    task = identify_task(dlem) 
    print(task, model_id, spec)
        
    for elem in glob(dlem+'/*'):
        
        if 'evaluation' in elem and not '.txt' in elem:
            print(elem)

            if 'original' in elem:
                df = pd.read_pickle(elem)
                df['test_data'] = 'original'
                
            else:
                df = pd.read_pickle(elem)
                df['test_data'] = 'equal'
            df['spec'] = spec
            df['model_id'] = model_id
            df['task'] = task
            
           # if acc_df==False:
            #    acc_df = df 
            #else:
            acc_df = pd.concat([acc_df, df])
# Out:
# res_models/models/IMDB_distbase_N_pro/e20do5_epoch18/
# IMDB distbase N_pro
# res_models/models/IMDB_distbase_N_pro/e20do5_epoch18/evaluation_N_pro
# res_models/models/IMDB_distbase_N_pro/e20do5_epoch18/evaluation_original
# res_models/models/IMDB_albertbase_N_pro/e20do5_epoch4/
# IMDB albertbase N_pro
# res_models/models/IMDB_albertbase_N_pro/e20do5_epoch4/evaluation_N_pro
# res_models/models/IMDB_albertbase_N_pro/e20do5_epoch4/evaluation_original
# res_models/models/IMDB_bertlarge_mix_weat/e20do5_epoch13/
# IMDB bertlarge mix_weat
# res_models/models/IMDB_bertlarge_mix_weat/e20do5_epoch13/evaluation_mix_weat
# res_models/models/IMDB_bertlarge_mix_weat/e20do5_epoch13/evaluation_original
# res_models/models/IMDB_bertlarge_mix_pro/e20do5_epoch19/
# IMDB bertlarge mix_pro
# res_models/models/IMDB_bertlarge_mix_pro/e20do5_epoch19/evaluation_mix_pro
# res_models/models/IMDB_bertlarge_mix_pro/e20do5_epoch19/evaluation_original
# res_models/models/IMDB_albertlarge_mix_pro/e20do5_epoch7/
# IMDB albertlarge mix_pro
# res_models/models/IMDB_albertlarge_mix_pro/e20do5_epoch7/evaluation_mix_pro
# res_models/models/IMDB_albertlarge_mix_pro/e20do5_epoch7/evaluation_original
# res_models/models/IMDB_bertlarge_N_pro/e20do5_epoch7/
# IMDB bertlarge N_pro
# res_models/models/IMDB_bertlarge_N_pro/e20do5_epoch7/evaluation_N_pro
# res_models/models/IMDB_bertlarge_N_pro/e20do5_epoch7/evaluation_original
# res_models/models/IMDB_bertlarge_N_weat/e20do5_epoch6/
# IMDB bertlarge N_weat
# res_models/models/IMDB_bertlarge_N_weat/e20do5_epoch6/evaluation_N_weat
# res_models/models/IMDB_bertlarge_N_weat/e20do5_epoch6/evaluation_original
# res_models/models/IMDB_robertabase_N_all/e20do5_epoch10/
# IMDB robertabase N_all
# res_models/models/IMDB_robertabase_N_all/e20do5_epoch10/evaluation_N_all
# res_models/models/IMDB_robertabase_N_all/e20do5_epoch10/evaluation_original
# res_models/models/IMDB_robertalarge_N_pro/e20do5_epoch10/
# IMDB robertalarge N_pro
# res_models/models/IMDB_robertalarge_N_pro/e20do5_epoch10/evaluation_N_pro
# res_models/models/IMDB_robertalarge_N_pro/e20do5_epoch10/evaluation_original
# res_models/models/IMDB_albertbase_N_all/e20do5_epoch5/
# IMDB albertbase N_all
# res_models/models/IMDB_albertbase_N_all/e20do5_epoch5/evaluation_N_all
# res_models/models/IMDB_albertbase_N_all/e20do5_epoch5/evaluation_original
# res_models/models/IMDB_distbase_N_all/e20do5_epoch16/
# IMDB distbase N_all
# res_models/models/IMDB_distbase_N_all/e20do5_epoch16/evaluation_N_all
# res_models/models/IMDB_distbase_N_all/e20do5_epoch16/evaluation_original
# res_models/models/IMDB_distbase_mix_pro/e20do5_epoch18/
# IMDB distbase mix_pro
# res_models/models/IMDB_distbase_mix_pro/e20do5_epoch18/evaluation_mix_pro
# res_models/models/IMDB_distbase_mix_pro/e20do5_epoch18/evaluation_original
# res_models/models/IMDB_bertlarge_N_all/e20do5_epoch19/
# IMDB bertlarge N_all
# res_models/models/IMDB_bertlarge_N_all/e20do5_epoch19/evaluation_N_all
# res_models/models/IMDB_bertlarge_N_all/e20do5_epoch19/evaluation_original
# res_models/models/IMDB_bertbase_original/e20do5_epoch10/
# IMDB bertbase original
# res_models/models/IMDB_bertbase_original/e20do5_epoch10/evaluation_original
# res_models/models/IMDB_albertbase_original/e20do5_epoch8/
# IMDB albertbase original
# res_models/models/IMDB_albertbase_original/e20do5_epoch8/evaluation_original
# res_models/models/IMDB_bertbase_N_all/e20do5_epoch12/
# IMDB bertbase N_all
# res_models/models/IMDB_bertbase_N_all/e20do5_epoch12/evaluation_N_all
# res_models/models/IMDB_bertbase_N_all/e20do5_epoch12/evaluation_original
# res_models/models/IMDB_albertlarge_N_all/e20do5_epoch17/
# IMDB albertlarge N_all
# res_models/models/IMDB_albertlarge_N_all/e20do5_epoch17/evaluation_N_all
# res_models/models/IMDB_albertlarge_N_all/e20do5_epoch17/evaluation_original
# res_models/models/IMDB_albertlarge_N_pro/e20do5_epoch11/
# IMDB albertlarge N_pro
# res_models/models/IMDB_albertlarge_N_pro/e20do5_epoch11/evaluation_N_pro
# res_models/models/IMDB_albertlarge_N_pro/e20do5_epoch11/evaluation_original
# res_models/models/IMDB_albertlarge_mix_weat/e20do5_epoch19/
# IMDB albertlarge mix_weat
# res_models/models/IMDB_albertlarge_mix_weat/e20do5_epoch19/evaluation_mix_weat
# res_models/models/IMDB_albertlarge_mix_weat/e20do5_epoch19/evaluation_original
# res_models/models/IMDB_bertbase_N_weat/e20do5_epoch12/
# IMDB bertbase N_weat
# res_models/models/IMDB_bertbase_N_weat/e20do5_epoch12/evaluation_N_weat
# res_models/models/IMDB_bertbase_N_weat/e20do5_epoch12/evaluation_original
# res_models/models/IMDB_albertlarge_original/e20do5_epoch12/
# IMDB albertlarge original
# res_models/models/IMDB_albertlarge_original/e20do5_epoch12/evaluation_original
# res_models/models/IMDB_robertalarge_mix_all/e20do5_epoch5/
# IMDB robertalarge mix_all
# res_models/models/IMDB_robertalarge_mix_all/e20do5_epoch5/evaluation_mix_all
# res_models/models/IMDB_robertalarge_mix_all/e20do5_epoch5/evaluation_original
# res_models/models/IMDB_albertbase_mix_weat/e20do5_epoch6/
# IMDB albertbase mix_weat
# res_models/models/IMDB_albertbase_mix_weat/e20do5_epoch6/evaluation_mix_weat
# res_models/models/IMDB_albertbase_mix_weat/e20do5_epoch6/evaluation_original
# res_models/models/IMDB_robertalarge_original/e20do5_epoch11/
# IMDB robertalarge original
# res_models/models/IMDB_robertalarge_original/e20do5_epoch11/evaluation_original
# res_models/models/IMDB_robertalarge_N_weat/e20do5_epoch14/
# IMDB robertalarge N_weat
# res_models/models/IMDB_robertalarge_N_weat/e20do5_epoch14/evaluation_N_weat
# res_models/models/IMDB_robertalarge_N_weat/e20do5_epoch14/evaluation_original
# res_models/models/IMDB_bertbase_mix_weat/e20do5_epoch10/
# IMDB bertbase mix_weat
# res_models/models/IMDB_bertbase_mix_weat/e20do5_epoch10/evaluation_mix_weat
# res_models/models/IMDB_bertbase_mix_weat/e20do5_epoch10/evaluation_original
# res_models/models/IMDB_distbase_N_weat/e20do5_epoch19/
# IMDB distbase N_weat
# res_models/models/IMDB_distbase_N_weat/e20do5_epoch19/evaluation_N_weat
# res_models/models/IMDB_distbase_N_weat/e20do5_epoch19/evaluation_original
# res_models/models/IMDB_robertalarge_mix_pro/e20do5_epoch5/
# IMDB robertalarge mix_pro
# res_models/models/IMDB_robertalarge_mix_pro/e20do5_epoch5/evaluation_mix_pro
# res_models/models/IMDB_robertalarge_mix_pro/e20do5_epoch5/evaluation_original
# res_models/models/IMDB_robertabase_N_weat/e20do5_epoch10/
# IMDB robertabase N_weat
# res_models/models/IMDB_robertabase_N_weat/e20do5_epoch10/evaluation_N_weat
# res_models/models/IMDB_robertabase_N_weat/e20do5_epoch10/evaluation_original
# res_models/models/IMDB_albertbase_mix_pro/e20do5_epoch13/
# IMDB albertbase mix_pro
# res_models/models/IMDB_albertbase_mix_pro/e20do5_epoch13/evaluation_mix_pro
# res_models/models/IMDB_albertbase_mix_pro/e20do5_epoch13/evaluation_original
# res_models/models/IMDB_distbase_mix_all/e20do5_epoch14/
# IMDB distbase mix_all
# res_models/models/IMDB_distbase_mix_all/e20do5_epoch14/evaluation_mix_all
# res_models/models/IMDB_distbase_mix_all/e20do5_epoch14/evaluation_original
# res_models/models/IMDB_robertalarge_N_all/e20do5_epoch15/
# IMDB robertalarge N_all
# res_models/models/IMDB_robertalarge_N_all/e20do5_epoch15/evaluation_N_all
# res_models/models/IMDB_robertalarge_N_all/e20do5_epoch15/evaluation_original
# res_models/models/IMDB_bertlarge_mix_all/e20do5_epoch14/
# IMDB bertlarge mix_all
# res_models/models/IMDB_bertlarge_mix_all/e20do5_epoch14/evaluation_mix_all
# res_models/models/IMDB_bertlarge_mix_all/e20do5_epoch14/evaluation_original
# res_models/models/IMDB_bertbase_mix_pro/e20do5_epoch5/
# IMDB bertbase mix_pro
# res_models/models/IMDB_bertbase_mix_pro/e20do5_epoch5/evaluation_mix_pro
# res_models/models/IMDB_bertbase_mix_pro/e20do5_epoch5/evaluation_original
# res_models/models/IMDB_distbase_mix_weat/e20do5_epoch19/
# IMDB distbase mix_weat
# res_models/models/IMDB_distbase_mix_weat/e20do5_epoch19/evaluation_mix_weat
# res_models/models/IMDB_distbase_mix_weat/e20do5_epoch19/evaluation_original
# res_models/models/IMDB_robertabase_N_pro/e20do5_epoch/
# IMDB robertabase N_pro
# res_models/models/IMDB_robertabase_N_pro/e20do5_epoch/evaluation_N_pro
# res_models/models/IMDB_robertabase_N_pro/e20do5_epoch/evaluation_original
# res_models/models/IMDB_robertabase_mix_weat/e20do5_epoch7/
# IMDB robertabase mix_weat
# res_models/models/IMDB_robertabase_mix_weat/e20do5_epoch7/evaluation_mix_weat
# res_models/models/IMDB_robertabase_mix_weat/e20do5_epoch7/evaluation_original
# res_models/models/IMDB_distbase_original/e20do5_epoch8/
# IMDB distbase original
# res_models/models/IMDB_distbase_original/e20do5_epoch8/evaluation_original
# res_models/models/IMDB_albertbase_N_weat/e20do5_epoch8/
# IMDB albertbase N_weat
# res_models/models/IMDB_albertbase_N_weat/e20do5_epoch8/evaluation_N_weat
# res_models/models/IMDB_albertbase_N_weat/e20do5_epoch8/evaluation_original
# res_models/models/IMDB_albertlarge_mix_all/e20do5_epoch18/
# IMDB albertlarge mix_all
# res_models/models/IMDB_albertlarge_mix_all/e20do5_epoch18/evaluation_mix_all
# res_models/models/IMDB_albertlarge_mix_all/e20do5_epoch18/evaluation_original
# res_models/models/IMDB_robertabase_mix_pro/e20do5_epoch4/
# IMDB robertabase mix_pro
# res_models/models/IMDB_robertabase_mix_pro/e20do5_epoch4/evaluation_mix_pro
# res_models/models/IMDB_robertabase_mix_pro/e20do5_epoch4/evaluation_original
# res_models/models/IMDB_robertalarge_mix_weat/e20do5_epoch5/
# IMDB robertalarge mix_weat
# res_models/models/IMDB_robertalarge_mix_weat/e20do5_epoch5/evaluation_mix_weat
# res_models/models/IMDB_robertalarge_mix_weat/e20do5_epoch5/evaluation_original
# res_models/models/IMDB_robertabase_original/e20do5_epoch8/
# IMDB robertabase original
# res_models/models/IMDB_robertabase_original/e20do5_epoch8/evaluation_original
# res_models/models/IMDB_bertlarge_original/e20do5_epoch13/
# IMDB bertlarge original
# res_models/models/IMDB_bertlarge_original/e20do5_epoch13/evaluation_original
# res_models/models/IMDB_albertbase_mix_all/e20do5_epoch19/
# IMDB albertbase mix_all
# res_models/models/IMDB_albertbase_mix_all/e20do5_epoch19/evaluation_mix_all
# res_models/models/IMDB_albertbase_mix_all/e20do5_epoch19/evaluation_original
# res_models/models/IMDB_bertbase_mix_all/e20do5_epoch12/
# IMDB bertbase mix_all
# res_models/models/IMDB_bertbase_mix_all/e20do5_epoch12/evaluation_mix_all
# res_models/models/IMDB_bertbase_mix_all/e20do5_epoch12/evaluation_original
# res_models/models/IMDB_albertlarge_N_weat/e20do5_epoch12/
# IMDB albertlarge N_weat
# res_models/models/IMDB_albertlarge_N_weat/e20do5_epoch12/evaluation_N_weat
# res_models/models/IMDB_albertlarge_N_weat/e20do5_epoch12/evaluation_original
# res_models/models/IMDB_robertabase_mix_all/e20do5_epoch11/
# IMDB robertabase mix_all
# res_models/models/IMDB_robertabase_mix_all/e20do5_epoch11/evaluation_mix_all
# res_models/models/IMDB_robertabase_mix_all/e20do5_epoch11/evaluation_original
# res_models/models/IMDB_bertbase_N_pro/e20do5_epoch11/
# IMDB bertbase N_pro
# res_models/models/IMDB_bertbase_N_pro/e20do5_epoch11/evaluation_N_pro
# res_models/models/IMDB_bertbase_N_pro/e20do5_epoch11/evaluation_original

# %%
acc_df = pd.DataFrame({ "batch":[], "accuracy":[], "recall":[], "precision":[], "f1":[], "spec":[], "model_id":[], "task":[]})

for dlem in glob("res_models/models/*/*['epoch']*/"):
    spec =  identify_spec(elem)
    if type(spec)==list: 
        spec.remove('original')
        assert(len(spec)==1)
        spec = spec[0]
    print(model_id, spec)
    model_id = identify_model_id(elem)
    task = identify_task(elem) 
    
    for elem in glob(dlem+'/*'):
        
        if 'evaluation' in elem and not '.txt' in elem:
            print(elem)            
            if 'original' in elem:
                df = pd.read_pickle(elem)
                df['test_data'] = 'original'
                
            else:
                df = pd.read_pickle(elem)
                df['test_data'] = 'equal'
            df['spec'] = spec
            df['model_id'] = model_id
            df['task'] = task
            
           # if acc_df==False:
            #    acc_df = df 
            #else:
            acc_df = pd.concat([acc_df, df])
acc_df.loc[acc_df.spec=='original', "test_data"]='equal'
# Out:
# robertabase N_pro
# res_models/models/IMDB_distbase_N_pro/e20do5_epoch18/evaluation_N_pro
# res_models/models/IMDB_distbase_N_pro/e20do5_epoch18/evaluation_original
# bertbase N_pro
# res_models/models/IMDB_albertbase_N_pro/e20do5_epoch4/evaluation_N_pro
# res_models/models/IMDB_albertbase_N_pro/e20do5_epoch4/evaluation_original
# distbase N_pro
# res_models/models/IMDB_bertlarge_mix_weat/e20do5_epoch13/evaluation_mix_weat
# res_models/models/IMDB_bertlarge_mix_weat/e20do5_epoch13/evaluation_original
# albertbase mix_weat
# res_models/models/IMDB_bertlarge_mix_pro/e20do5_epoch19/evaluation_mix_pro
# res_models/models/IMDB_bertlarge_mix_pro/e20do5_epoch19/evaluation_original
# bertlarge mix_pro
# res_models/models/IMDB_albertlarge_mix_pro/e20do5_epoch7/evaluation_mix_pro
# res_models/models/IMDB_albertlarge_mix_pro/e20do5_epoch7/evaluation_original
# bertlarge mix_pro
# res_models/models/IMDB_bertlarge_N_pro/e20do5_epoch7/evaluation_N_pro
# res_models/models/IMDB_bertlarge_N_pro/e20do5_epoch7/evaluation_original
# albertlarge N_pro
# res_models/models/IMDB_bertlarge_N_weat/e20do5_epoch6/evaluation_N_weat
# res_models/models/IMDB_bertlarge_N_weat/e20do5_epoch6/evaluation_original
# bertlarge N_weat
# res_models/models/IMDB_robertabase_N_all/e20do5_epoch10/evaluation_N_all
# res_models/models/IMDB_robertabase_N_all/e20do5_epoch10/evaluation_original
# bertlarge N_all
# res_models/models/IMDB_robertalarge_N_pro/e20do5_epoch10/evaluation_N_pro
# res_models/models/IMDB_robertalarge_N_pro/e20do5_epoch10/evaluation_original
# robertabase N_pro
# res_models/models/IMDB_albertbase_N_all/e20do5_epoch5/evaluation_N_all
# res_models/models/IMDB_albertbase_N_all/e20do5_epoch5/evaluation_original
# robertalarge N_all
# res_models/models/IMDB_distbase_N_all/e20do5_epoch16/evaluation_N_all
# res_models/models/IMDB_distbase_N_all/e20do5_epoch16/evaluation_original
# albertbase N_all
# res_models/models/IMDB_distbase_mix_pro/e20do5_epoch18/evaluation_mix_pro
# res_models/models/IMDB_distbase_mix_pro/e20do5_epoch18/evaluation_original
# distbase mix_pro
# res_models/models/IMDB_bertlarge_N_all/e20do5_epoch19/evaluation_N_all
# res_models/models/IMDB_bertlarge_N_all/e20do5_epoch19/evaluation_original
# distbase N_all
# res_models/models/IMDB_bertbase_original/e20do5_epoch10/evaluation_original
# bertlarge original
# res_models/models/IMDB_albertbase_original/e20do5_epoch8/evaluation_original
# bertbase original
# res_models/models/IMDB_bertbase_N_all/e20do5_epoch12/evaluation_N_all
# res_models/models/IMDB_bertbase_N_all/e20do5_epoch12/evaluation_original
# albertbase N_all
# res_models/models/IMDB_albertlarge_N_all/e20do5_epoch17/evaluation_N_all
# res_models/models/IMDB_albertlarge_N_all/e20do5_epoch17/evaluation_original
# bertbase N_all
# res_models/models/IMDB_albertlarge_N_pro/e20do5_epoch11/evaluation_N_pro
# res_models/models/IMDB_albertlarge_N_pro/e20do5_epoch11/evaluation_original
# albertlarge N_pro
# res_models/models/IMDB_albertlarge_mix_weat/e20do5_epoch19/evaluation_mix_weat
# res_models/models/IMDB_albertlarge_mix_weat/e20do5_epoch19/evaluation_original
# albertlarge mix_weat
# res_models/models/IMDB_bertbase_N_weat/e20do5_epoch12/evaluation_N_weat
# res_models/models/IMDB_bertbase_N_weat/e20do5_epoch12/evaluation_original
# albertlarge N_weat
# res_models/models/IMDB_albertlarge_original/e20do5_epoch12/evaluation_original
# bertbase original
# res_models/models/IMDB_robertalarge_mix_all/e20do5_epoch5/evaluation_mix_all
# res_models/models/IMDB_robertalarge_mix_all/e20do5_epoch5/evaluation_original
# albertlarge mix_all
# res_models/models/IMDB_albertbase_mix_weat/e20do5_epoch6/evaluation_mix_weat
# res_models/models/IMDB_albertbase_mix_weat/e20do5_epoch6/evaluation_original
# robertalarge mix_weat
# res_models/models/IMDB_robertalarge_original/e20do5_epoch11/evaluation_original
# albertbase original
# res_models/models/IMDB_robertalarge_N_weat/e20do5_epoch14/evaluation_N_weat
# res_models/models/IMDB_robertalarge_N_weat/e20do5_epoch14/evaluation_original
# robertalarge N_weat
# res_models/models/IMDB_bertbase_mix_weat/e20do5_epoch10/evaluation_mix_weat
# res_models/models/IMDB_bertbase_mix_weat/e20do5_epoch10/evaluation_original
# robertalarge mix_weat
# res_models/models/IMDB_distbase_N_weat/e20do5_epoch19/evaluation_N_weat
# res_models/models/IMDB_distbase_N_weat/e20do5_epoch19/evaluation_original
# bertbase N_weat
# res_models/models/IMDB_robertalarge_mix_pro/e20do5_epoch5/evaluation_mix_pro
# res_models/models/IMDB_robertalarge_mix_pro/e20do5_epoch5/evaluation_original
# distbase mix_pro
# res_models/models/IMDB_robertabase_N_weat/e20do5_epoch10/evaluation_N_weat
# res_models/models/IMDB_robertabase_N_weat/e20do5_epoch10/evaluation_original
# robertalarge N_weat
# res_models/models/IMDB_albertbase_mix_pro/e20do5_epoch13/evaluation_mix_pro
# res_models/models/IMDB_albertbase_mix_pro/e20do5_epoch13/evaluation_original
# robertabase mix_pro
# res_models/models/IMDB_distbase_mix_all/e20do5_epoch14/evaluation_mix_all
# res_models/models/IMDB_distbase_mix_all/e20do5_epoch14/evaluation_original
# albertbase mix_all
# res_models/models/IMDB_robertalarge_N_all/e20do5_epoch15/evaluation_N_all
# res_models/models/IMDB_robertalarge_N_all/e20do5_epoch15/evaluation_original
# distbase N_all
# res_models/models/IMDB_bertlarge_mix_all/e20do5_epoch14/evaluation_mix_all
# res_models/models/IMDB_bertlarge_mix_all/e20do5_epoch14/evaluation_original
# robertalarge mix_all
# res_models/models/IMDB_bertbase_mix_pro/e20do5_epoch5/evaluation_mix_pro
# res_models/models/IMDB_bertbase_mix_pro/e20do5_epoch5/evaluation_original
# bertlarge mix_pro
# res_models/models/IMDB_distbase_mix_weat/e20do5_epoch19/evaluation_mix_weat
# res_models/models/IMDB_distbase_mix_weat/e20do5_epoch19/evaluation_original
# bertbase mix_weat
# res_models/models/IMDB_robertabase_N_pro/e20do5_epoch/evaluation_N_pro
# res_models/models/IMDB_robertabase_N_pro/e20do5_epoch/evaluation_original
# distbase N_pro
# res_models/models/IMDB_robertabase_mix_weat/e20do5_epoch7/evaluation_mix_weat
# res_models/models/IMDB_robertabase_mix_weat/e20do5_epoch7/evaluation_original
# robertabase mix_weat
# res_models/models/IMDB_distbase_original/e20do5_epoch8/evaluation_original
# robertabase original
# res_models/models/IMDB_albertbase_N_weat/e20do5_epoch8/evaluation_N_weat
# res_models/models/IMDB_albertbase_N_weat/e20do5_epoch8/evaluation_original
# distbase N_weat
# res_models/models/IMDB_albertlarge_mix_all/e20do5_epoch18/evaluation_mix_all
# res_models/models/IMDB_albertlarge_mix_all/e20do5_epoch18/evaluation_original
# albertbase mix_all
# res_models/models/IMDB_robertabase_mix_pro/e20do5_epoch4/evaluation_mix_pro
# res_models/models/IMDB_robertabase_mix_pro/e20do5_epoch4/evaluation_original
# albertlarge mix_pro
# res_models/models/IMDB_robertalarge_mix_weat/e20do5_epoch5/evaluation_mix_weat
# res_models/models/IMDB_robertalarge_mix_weat/e20do5_epoch5/evaluation_original
# robertabase mix_weat
# res_models/models/IMDB_robertabase_original/e20do5_epoch8/evaluation_original
# robertalarge original
# res_models/models/IMDB_bertlarge_original/e20do5_epoch13/evaluation_original
# robertabase original
# res_models/models/IMDB_albertbase_mix_all/e20do5_epoch19/evaluation_mix_all
# res_models/models/IMDB_albertbase_mix_all/e20do5_epoch19/evaluation_original
# bertlarge mix_all
# res_models/models/IMDB_bertbase_mix_all/e20do5_epoch12/evaluation_mix_all
# res_models/models/IMDB_bertbase_mix_all/e20do5_epoch12/evaluation_original
# albertbase mix_all
# res_models/models/IMDB_albertlarge_N_weat/e20do5_epoch12/evaluation_N_weat
# res_models/models/IMDB_albertlarge_N_weat/e20do5_epoch12/evaluation_original
# bertbase N_weat
# res_models/models/IMDB_robertabase_mix_all/e20do5_epoch11/evaluation_mix_all
# res_models/models/IMDB_robertabase_mix_all/e20do5_epoch11/evaluation_original
# albertlarge mix_all
# res_models/models/IMDB_bertbase_N_pro/e20do5_epoch11/evaluation_N_pro
# res_models/models/IMDB_bertbase_N_pro/e20do5_epoch11/evaluation_original

# %%
#acc_df=acc_df.sort_values(['model_id', 'spec'])
acc_df
# Out:
#    batch  accuracy   recall  precision        f1      spec      model_id  \
# 0  final   0.77144  0.71136   0.808511  0.756830     N_all    albertbase
# 0  final   0.76948  0.70304   0.810776  0.753074     N_all    albertbase
# 0  final   0.75860  0.74800   0.764201  0.756014     N_pro    albertbase
# 0  final   0.75832  0.73928   0.768546  0.753629     N_pro    albertbase
# 0  final   0.77192  0.74904   0.784960  0.766579    N_weat    albertbase
# 0  final   0.77092  0.74000   0.788778  0.763611    N_weat    albertbase
# 0  final   0.78164  0.79100   0.776465  0.783665   mix_all    albertbase
# 0  final   0.78216  0.79096   0.777280  0.784060   mix_all    albertbase
# 0  final   0.77970  0.81332   0.762078  0.786866   mix_pro    albertbase
# 0  final   0.77980  0.81328   0.762240  0.786933   mix_pro    albertbase
# 0  final   0.77754  0.81796   0.756782  0.786183  mix_weat    albertbase
# 0  final   0.77696  0.81808   0.755914  0.785769  mix_weat    albertbase
# 0  final   0.69288  0.93224   0.630437  0.752195  original    albertbase
# 0  final   0.76212  0.84680   0.724157  0.780691     N_all   albertlarge
# 0  final   0.76140  0.84104   0.725485  0.779000     N_all   albertlarge
# 0  final   0.76344  0.83168   0.731803  0.778552     N_pro   albertlarge
# 0  final   0.76264  0.82680   0.732771  0.776951     N_pro   albertlarge
# 0  final   0.76712  0.80176   0.749813  0.774917    N_weat   albertlarge
# 0  final   0.76544  0.79688   0.749737  0.772590    N_weat   albertlarge
# 0  final   0.77424  0.80276   0.759441  0.780500   mix_all   albertlarge
# 0  final   0.77432  0.80144   0.760206  0.780279   mix_all   albertlarge
# 0  final   0.78236  0.75184   0.800716  0.775509   mix_pro   albertlarge
# 0  final   0.78256  0.75208   0.800903  0.775724   mix_pro   albertlarge
# 0  final   0.78370  0.78776   0.781415  0.784575  mix_weat   albertlarge
# 0  final   0.78364  0.78784   0.781277  0.784545  mix_weat   albertlarge
# 0  final   0.78372  0.76224   0.796456  0.778972  original   albertlarge
# 0  final   0.82088  0.78096   0.848722  0.813432     N_all      bertbase
# 0  final   0.82032  0.77976   0.848598  0.812724     N_all      bertbase
# 0  final   0.82008  0.77568   0.851273  0.811720     N_pro      bertbase
# 0  final   0.82060  0.77376   0.853738  0.811784     N_pro      bertbase
# 0  final   0.82080  0.80248   0.833001  0.817456    N_weat      bertbase
# 0  final   0.81972  0.79808   0.834183  0.815732    N_weat      bertbase
# 0  final   0.83550  0.79124   0.868083  0.827882   mix_all      bertbase
# 0  final   0.83588  0.79192   0.868257  0.828334   mix_all      bertbase
# 0  final   0.83540  0.81552   0.849288  0.832061   mix_pro      bertbase
# 0  final   0.83576  0.81576   0.849750  0.832408   mix_pro      bertbase
# 0  final   0.83542  0.81184   0.852021  0.831445  mix_weat      bertbase
# 0  final   0.83540  0.81224   0.851690  0.831497  mix_weat      bertbase
# 0  final   0.81752  0.78672   0.838363  0.811721  original      bertbase
# 0  final   0.79648  0.73360   0.839129  0.782824     N_all     bertlarge
# 0  final   0.79592  0.72800   0.842437  0.781049     N_all     bertlarge
# 0  final   0.77940  0.65984   0.867206  0.749443     N_pro     bertlarge
# 0  final   0.77668  0.64712   0.873448  0.743440     N_pro     bertlarge
# 0  final   0.80264  0.73920   0.846619  0.789271    N_weat     bertlarge
# 0  final   0.80028  0.72696   0.851880  0.784478    N_weat     bertlarge
# 0  final   0.79536  0.72332   0.845079  0.779473   mix_all     bertlarge
# 0  final   0.79528  0.72240   0.845664  0.779187   mix_all     bertlarge
# 0  final   0.79656  0.73784   0.836022  0.783869   mix_pro     bertlarge
# 0  final   0.79652  0.73752   0.836190  0.783762   mix_pro     bertlarge
# 0  final   0.78886  0.71024   0.842755  0.770844  mix_weat     bertlarge
# 0  final   0.78912  0.70976   0.843667  0.770942  mix_weat     bertlarge
# 0  final   0.80456  0.78720   0.815515  0.801107  original     bertlarge
# 0  final   0.81732  0.78896   0.836401  0.811988     N_all      distbase
# 0  final   0.81568  0.78592   0.835658  0.810026     N_all      distbase
# 0  final   0.81768  0.77960   0.843869  0.810462     N_pro      distbase
# 0  final   0.81736  0.77616   0.845859  0.809512     N_pro      distbase
# 0  final   0.81948  0.78936   0.839959  0.813874    N_weat      distbase
# 0  final   0.81784  0.78456   0.840504  0.811569    N_weat      distbase
# 0  final   0.82184  0.79472   0.840298  0.816874   mix_all      distbase
# 0  final   0.82200  0.79456   0.840697  0.816978   mix_all      distbase
# 0  final   0.82154  0.78364   0.847912  0.814510   mix_pro      distbase
# 0  final   0.82132  0.78392   0.847298  0.814378   mix_pro      distbase
# 0  final   0.82206  0.78328   0.849139  0.814881  mix_weat      distbase
# 0  final   0.82216  0.78344   0.849202  0.814997  mix_weat      distbase
# 0  final   0.81176  0.77760   0.834621  0.805102  original      distbase
# 0  final   0.82316  0.77008   0.861541  0.813247     N_all   robertabase
# 0  final   0.82216  0.76712   0.862010  0.811802     N_all   robertabase
# 0  final   0.81764  0.73288   0.882478  0.800752     N_pro   robertabase
# 0  final   0.81712  0.72808   0.885828  0.799245     N_pro   robertabase
# 0  final   0.81972  0.73928   0.881018  0.803950    N_weat   robertabase
# 0  final   0.81932  0.73448   0.884575  0.802570    N_weat   robertabase
# 0  final   0.83316  0.78040   0.872462  0.823867   mix_all   robertabase
# 0  final   0.83292  0.78024   0.872127  0.823629   mix_all   robertabase
# 0  final   0.82324  0.76032   0.869772  0.811371   mix_pro   robertabase
# 0  final   0.82332  0.76064   0.869661  0.811505   mix_pro   robertabase
# 0  final   0.83022  0.78056   0.866634  0.821348  mix_weat   robertabase
# 0  final   0.83020  0.78120   0.866075  0.821451  mix_weat   robertabase
# 0  final   0.81812  0.74376   0.873696  0.803509  original   robertabase
# 0  final   0.81984  0.76528   0.859016  0.809443     N_all  robertalarge
# 0  final   0.82024  0.76224   0.862262  0.809172     N_all  robertalarge
# 0  final   0.81812  0.75064   0.867752  0.804959     N_pro  robertalarge
# 0  final   0.81708  0.74536   0.870178  0.802947     N_pro  robertalarge
# 0  final   0.81972  0.76096   0.862297  0.808465    N_weat  robertalarge
# 0  final   0.81944  0.75864   0.863661  0.807751    N_weat  robertalarge
# 0  final   0.81456  0.74848   0.862463  0.801439   mix_all  robertalarge
# 0  final   0.81468  0.74864   0.862568  0.801576   mix_all  robertalarge
# 0  final   0.81410  0.72812   0.879330  0.796613   mix_pro  robertalarge
# 0  final   0.81404  0.72824   0.879092  0.796587   mix_pro  robertalarge
# 0  final   0.81620  0.76140   0.855121  0.805544  mix_weat  robertalarge
# 0  final   0.81656  0.76240   0.855015  0.806056  mix_weat  robertalarge
# 0  final   0.81956  0.74824   0.872726  0.805703  original  robertalarge
#
#    task test_data
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB     equal
# 0  IMDB  original
# 0  IMDB  original

# %%
print(pd.get_option("display.max_columns"))
pd.set_option("display.max_rows", None)
# Out:
# 20

# %%
pd.set_option("display.max_rows", None)

# %%
acc_df.shape
# Out:
# (91, 9)

# %%
acc_df.head()
# Out:
#    batch  accuracy   recall  precision        f1      spec    model_id  task  \
# 0  final   0.81768  0.77960   0.843869  0.810462     N_pro    distbase  IMDB
# 0  final   0.81736  0.77616   0.845859  0.809512     N_pro    distbase  IMDB
# 0  final   0.75860  0.74800   0.764201  0.756014     N_pro  albertbase  IMDB
# 0  final   0.75832  0.73928   0.768546  0.753629     N_pro  albertbase  IMDB
# 0  final   0.78886  0.71024   0.842755  0.770844  mix_weat   bertlarge  IMDB
#
#   test_data
# 0     equal
# 0  original
# 0     equal
# 0  original
# 0     equal

# %%
acc_df.to_pickle('res_results/IMDB_evaluation_df')

# %%
specs = ["N_pro", "N_weat", "N_all", "mix_pro", "mix_weat", "mix_all", "original" ]
    
model_ids = ["albertbase", "albertlarge", "bertbase", "bertlarge", "distbase", "robertabase", "robertalarge"]

for model in model_ids:
    for spec in specs:
        df = acc_df
        df = df.loc[(df['spec']== spec) & (df['model_id'] == model ),['accuracy','recall', 'precision', 'f1', 'test_data']]
        print('### ### ### ### ### ')
        print(model, spec)
        
        acc_l = df['accuracy'].tolist()
        rec_l = df['recall'].tolist()
        pre_l = df['precision'].tolist()
        f1_l = df['f1'].tolist()
        teda_l = df['test_data'].tolist()
        
        if len(teda_l) ==1 : 
            print('only one line --- ')
        else:
            if teda_l[0] == "original":
                print('ERROR: messed up')
                #factor = 1
            #elif teda_l[1] == "original":
            #    factor = -1
            
            # print(factor)
            print('accuracy', acc_l[0]- acc_l[1], 'recall', rec_l[0]- rec_l[1], 'precision', pre_l[0]- pre_l[1], 'f1', f1_l[0]-f1_l[1])
            #print('test_data', teda_l[0]-teda_l[1])
# Out:
# ### ### ### ### ###
# albertbase N_pro
# accuracy 0.000280000000000058 recall 0.00871999999999995 precision -0.004345178326088606 f1 0.0023846476780442494
# ### ### ### ### ###
# albertbase N_weat
# accuracy 0.0010000000000000009 recall 0.009040000000000048 precision -0.0038182750463727766 f1 0.002968487787467944
# ### ### ### ### ###
# albertbase N_all
# accuracy 0.0019599999999999618 recall 0.008319999999999994 precision -0.002265263538090423 f1 0.003756115146399508
# ### ### ### ### ###
# albertbase mix_pro
# accuracy -0.00010000000000010001 recall 4.0000000000040004e-05 precision -0.00016250075661561336 f1 -6.788828142945125e-05
# ### ### ### ### ###
# albertbase mix_weat
# accuracy 0.0005800000000000249 recall -0.00012000000000000899 precision 0.0008681017771161592 f1 0.00041333155856571047
# ### ### ### ### ###
# albertbase mix_all
# accuracy -0.0005199999999999649 recall 4.0000000000040004e-05 precision -0.0008152912077111774 f1 -0.0003953730591574889
# ### ### ### ### ###
# albertbase original
# only one line ---
# ### ### ### ### ###
# albertlarge N_pro
# accuracy 0.0008000000000000229 recall 0.0048799999999999955 precision -0.0009673818249564814 f1 0.0016008018754203324
# ### ### ### ### ###
# albertlarge N_weat
# accuracy 0.0016800000000000148 recall 0.0048799999999999955 precision 7.6393447223988e-05 f1 0.0023271019024245776
# ### ### ### ### ###
# albertlarge N_all
# accuracy 0.0007200000000000539 recall 0.005759999999999987 precision -0.0013279799371288536 f1 0.00169067185343319
# ### ### ### ### ###
# albertlarge mix_pro
# accuracy -0.00019999999999997797 recall -0.00024000000000001798 precision -0.00018736448411660334 f1 -0.00021554961135272777
# ### ### ### ### ###
# albertlarge mix_weat
# accuracy 5.999999999994898e-05 recall -7.999999999996898e-05 precision 0.00013763999906635238 f1 2.971564208509303e-05
# ### ### ### ### ###
# albertlarge mix_all
# accuracy -7.999999999996898e-05 recall 0.0013199999999999878 precision -0.0007649454447500315 f1 0.00022129820219130014
# ### ### ### ### ###
# albertlarge original
# only one line ---
# ### ### ### ### ###
# bertbase N_pro
# accuracy -0.0005199999999999649 recall 0.0019200000000000328 precision -0.002465147483313168 f1 -6.35756217632899e-05
# ### ### ### ### ###
# bertbase N_weat
# accuracy 0.0010799999999999699 recall 0.0043999999999999595 precision -0.00118229755795618 f1 0.0017233398513368803
# ### ### ### ### ###
# bertbase N_all
# accuracy 0.0005600000000000049 recall 0.0011999999999999789 precision 0.00012366782323103287 f1 0.00070812493022121
# ### ### ### ### ###
# bertbase mix_pro
# accuracy -0.00035999999999991594 recall -0.00024000000000001798 precision -0.0004623219195201145 f1 -0.00034678302615165357
# ### ### ### ### ###
# bertbase mix_weat
# accuracy 2.0000000000020002e-05 recall -0.00039999999999995595 precision 0.0003310312826164674 f1 -5.1997150505189715e-05
# ### ### ### ### ###
# bertbase mix_all
# accuracy -0.00037999999999993594 recall -0.0006799999999999029 precision -0.0001744917033240645 f1 -0.0004514825551311663
# ### ### ### ### ###
# bertbase original
# only one line ---
# ### ### ### ### ###
# bertlarge N_pro
# accuracy 0.0027199999999999447 recall 0.012719999999999954 precision -0.006241399217094434 f1 0.006003360827993354
# ### ### ### ### ###
# bertlarge N_weat
# accuracy 0.0023600000000000287 recall 0.012239999999999918 precision -0.005260607321249333 f1 0.00479345491877925
# ### ### ### ### ###
# bertlarge N_all
# accuracy 0.0005600000000000049 recall 0.005600000000000049 precision -0.0033077424792273824 f1 0.0017751343066749747
# ### ### ### ### ###
# bertlarge mix_pro
# accuracy 4.0000000000040004e-05 recall 0.000320000000000098 precision -0.00016799613246309963 f1 0.00010681906818110765
# ### ### ### ### ###
# bertlarge mix_weat
# accuracy -0.000260000000000038 recall 0.00048000000000003595 precision -0.0009120352820699562 f1 -9.821902530271487e-05
# ### ### ### ### ###
# bertlarge mix_all
# accuracy 7.999999999996898e-05 recall 0.0009199999999999209 precision -0.0005850026752408644 f1 0.00028609291930659086
# ### ### ### ### ###
# bertlarge original
# only one line ---
# ### ### ### ### ###
# distbase N_pro
# accuracy 0.00031999999999998696 recall 0.0034399999999999986 precision -0.001989693750870103 f1 0.0009505186539726651
# ### ### ### ### ###
# distbase N_weat
# accuracy 0.0016399999999999748 recall 0.0047999999999999154 precision -0.0005448039031343832 f1 0.002304864423076425
# ### ### ### ### ###
# distbase N_all
# accuracy 0.0016400000000000858 recall 0.0030400000000000427 precision 0.0007422573528769183 f1 0.0019615938626302842
# ### ### ### ### ###
# distbase mix_pro
# accuracy 0.00021999999999999797 recall -0.00027999999999994696 precision 0.0006138258835091115 f1 0.00013219921369367338
# ### ### ### ### ###
# distbase mix_weat
# accuracy -9.999999999998899e-05 recall -0.000160000000000049 precision -6.298050129094346e-05 f1 -0.00011558248864329546
# ### ### ### ### ###
# distbase mix_all
# accuracy -0.00015999999999993797 recall 0.00015999999999993797 precision -0.00039972761127993195 f1 -0.00010426046306410974
# ### ### ### ### ###
# distbase original
# only one line ---
# ### ### ### ### ###
# robertabase N_pro
# accuracy 0.000520000000000076 recall 0.0048000000000000265 precision -0.0033507011441085144 f1 0.0015069626087869104
# ### ### ### ### ###
# robertabase N_weat
# accuracy 0.00039999999999995595 recall 0.0048000000000000265 precision -0.00355641227968162 f1 0.001379672684168054
# ### ### ### ### ###
# robertabase N_all
# accuracy 0.0010000000000000009 recall 0.0029599999999999627 precision -0.0004688528906933165 f1 0.0014456014730217515
# ### ### ### ### ###
# robertabase mix_pro
# accuracy -8.000000000008001e-05 recall -0.00031999999999998696 precision 0.0001114637102879179 f1 -0.00013364789115455356
# ### ### ### ### ###
# robertabase mix_weat
# accuracy 1.999999999990898e-05 recall -0.0006399999999999739 precision 0.0005587106543890608 f1 -0.00010295501746038216
# ### ### ### ### ###
# robertabase mix_all
# accuracy 0.00024000000000001798 recall 0.00015999999999993797 precision 0.00033487654702357705 f1 0.00023847208844629542
# ### ### ### ### ###
# robertabase original
# only one line ---
# ### ### ### ### ###
# robertalarge N_pro
# accuracy 0.0010399999999999299 recall 0.005279999999999951 precision -0.002426607705990236 f1 0.0020112202215146757
# ### ### ### ### ###
# robertalarge N_weat
# accuracy 0.000280000000000058 recall 0.0023199999999999887 precision -0.0013640396438650004 f1 0.000714150900436028
# ### ### ### ### ###
# robertalarge N_all
# accuracy -0.00039999999999995595 recall 0.0030399999999999316 precision -0.003246638841212901 f1 0.00027124768112551934
# ### ### ### ### ###
# robertalarge mix_pro
# accuracy 6.0000000000060005e-05 recall -0.00012000000000000899 precision 0.00023727501250181415 f1 2.558553686871079e-05
# ### ### ### ### ###
# robertalarge mix_weat
# accuracy -0.00035999999999991594 recall -0.0010000000000000009 precision 0.00010604169215933101 f1 -0.0005121923029661746
# ### ### ### ### ###
# robertalarge mix_all
# accuracy -0.00012000000000000899 recall -0.00015999999999993797 precision -0.00010485177188279682 f1 -0.000136989203159521
# ### ### ### ### ###
# robertalarge original
# only one line ---

# %%
print(acc_df.columns)
# Out:
# Index(['batch', 'accuracy', 'recall', 'precision', 'f1', 'spec', 'model_id',
#        'task', 'test_data'],
#       dtype='object')

# %%
acc_df.loc[acc_df.spec=='original', "test_data"]='equal'

# %%
acc_df_short = acc_df.loc[acc_df.test_data=='equal', ['model_id', 'spec', 'accuracy', 'recall', 'precision', 'f1' ]]
acc_df_short= acc_df_short.sort_values(by=["model_id", "spec"])
acc_df_short
# Out:
#        model_id      spec  accuracy   recall  precision        f1
# 0    albertbase     N_all   0.77144  0.71136   0.808511  0.756830
# 0    albertbase     N_pro   0.75860  0.74800   0.764201  0.756014
# 0    albertbase    N_weat   0.77192  0.74904   0.784960  0.766579
# 0    albertbase   mix_all   0.78164  0.79100   0.776465  0.783665
# 0    albertbase   mix_pro   0.77970  0.81332   0.762078  0.786866
# 0    albertbase  mix_weat   0.77754  0.81796   0.756782  0.786183
# 0    albertbase  original   0.69288  0.93224   0.630437  0.752195
# 0   albertlarge     N_all   0.76212  0.84680   0.724157  0.780691
# 0   albertlarge     N_pro   0.76344  0.83168   0.731803  0.778552
# 0   albertlarge    N_weat   0.76712  0.80176   0.749813  0.774917
# 0   albertlarge   mix_all   0.77424  0.80276   0.759441  0.780500
# 0   albertlarge   mix_pro   0.78236  0.75184   0.800716  0.775509
# 0   albertlarge  mix_weat   0.78370  0.78776   0.781415  0.784575
# 0   albertlarge  original   0.78372  0.76224   0.796456  0.778972
# 0      bertbase     N_all   0.82088  0.78096   0.848722  0.813432
# 0      bertbase     N_pro   0.82008  0.77568   0.851273  0.811720
# 0      bertbase    N_weat   0.82080  0.80248   0.833001  0.817456
# 0      bertbase   mix_all   0.83550  0.79124   0.868083  0.827882
# 0      bertbase   mix_pro   0.83540  0.81552   0.849288  0.832061
# 0      bertbase  mix_weat   0.83542  0.81184   0.852021  0.831445
# 0      bertbase  original   0.81752  0.78672   0.838363  0.811721
# 0     bertlarge     N_all   0.79648  0.73360   0.839129  0.782824
# 0     bertlarge     N_pro   0.77940  0.65984   0.867206  0.749443
# 0     bertlarge    N_weat   0.80264  0.73920   0.846619  0.789271
# 0     bertlarge   mix_all   0.79536  0.72332   0.845079  0.779473
# 0     bertlarge   mix_pro   0.79656  0.73784   0.836022  0.783869
# 0     bertlarge  mix_weat   0.78886  0.71024   0.842755  0.770844
# 0     bertlarge  original   0.80456  0.78720   0.815515  0.801107
# 0      distbase     N_all   0.81732  0.78896   0.836401  0.811988
# 0      distbase     N_pro   0.81768  0.77960   0.843869  0.810462
# 0      distbase    N_weat   0.81948  0.78936   0.839959  0.813874
# 0      distbase   mix_all   0.82184  0.79472   0.840298  0.816874
# 0      distbase   mix_pro   0.82154  0.78364   0.847912  0.814510
# 0      distbase  mix_weat   0.82206  0.78328   0.849139  0.814881
# 0      distbase  original   0.81176  0.77760   0.834621  0.805102
# 0   robertabase     N_all   0.82316  0.77008   0.861541  0.813247
# 0   robertabase     N_pro   0.81764  0.73288   0.882478  0.800752
# 0   robertabase    N_weat   0.81972  0.73928   0.881018  0.803950
# 0   robertabase   mix_all   0.83316  0.78040   0.872462  0.823867
# 0   robertabase   mix_pro   0.82324  0.76032   0.869772  0.811371
# 0   robertabase  mix_weat   0.83022  0.78056   0.866634  0.821348
# 0   robertabase  original   0.81812  0.74376   0.873696  0.803509
# 0  robertalarge     N_all   0.81984  0.76528   0.859016  0.809443
# 0  robertalarge     N_pro   0.81812  0.75064   0.867752  0.804959
# 0  robertalarge    N_weat   0.81972  0.76096   0.862297  0.808465
# 0  robertalarge   mix_all   0.81456  0.74848   0.862463  0.801439
# 0  robertalarge   mix_pro   0.81410  0.72812   0.879330  0.796613
# 0  robertalarge  mix_weat   0.81620  0.76140   0.855121  0.805544
# 0  robertalarge  original   0.81956  0.74824   0.872726  0.805703

# %%
print(acc_df_short.to_latex())
# Out:
# \begin{tabular}{lllrrrr}
# \toprule
# {} &      model\_id &      spec &  accuracy &   recall &  precision &        f1 \\
# \midrule
# 0 &    albertbase &     N\_all &   0.77144 &  0.71136 &   0.808511 &  0.756830 \\
# 0 &    albertbase &     N\_pro &   0.75860 &  0.74800 &   0.764201 &  0.756014 \\
# 0 &    albertbase &    N\_weat &   0.77192 &  0.74904 &   0.784960 &  0.766579 \\
# 0 &    albertbase &   mix\_all &   0.78164 &  0.79100 &   0.776465 &  0.783665 \\
# 0 &    albertbase &   mix\_pro &   0.77970 &  0.81332 &   0.762078 &  0.786866 \\
# 0 &    albertbase &  mix\_weat &   0.77754 &  0.81796 &   0.756782 &  0.786183 \\
# 0 &    albertbase &  original &   0.69288 &  0.93224 &   0.630437 &  0.752195 \\
# 0 &   albertlarge &     N\_all &   0.76212 &  0.84680 &   0.724157 &  0.780691 \\
# 0 &   albertlarge &     N\_pro &   0.76344 &  0.83168 &   0.731803 &  0.778552 \\
# 0 &   albertlarge &    N\_weat &   0.76712 &  0.80176 &   0.749813 &  0.774917 \\
# 0 &   albertlarge &   mix\_all &   0.77424 &  0.80276 &   0.759441 &  0.780500 \\
# 0 &   albertlarge &   mix\_pro &   0.78236 &  0.75184 &   0.800716 &  0.775509 \\
# 0 &   albertlarge &  mix\_weat &   0.78370 &  0.78776 &   0.781415 &  0.784575 \\
# 0 &   albertlarge &  original &   0.78372 &  0.76224 &   0.796456 &  0.778972 \\
# 0 &      bertbase &     N\_all &   0.82088 &  0.78096 &   0.848722 &  0.813432 \\
# 0 &      bertbase &     N\_pro &   0.82008 &  0.77568 &   0.851273 &  0.811720 \\
# 0 &      bertbase &    N\_weat &   0.82080 &  0.80248 &   0.833001 &  0.817456 \\
# 0 &      bertbase &   mix\_all &   0.83550 &  0.79124 &   0.868083 &  0.827882 \\
# 0 &      bertbase &   mix\_pro &   0.83540 &  0.81552 &   0.849288 &  0.832061 \\
# 0 &      bertbase &  mix\_weat &   0.83542 &  0.81184 &   0.852021 &  0.831445 \\
# 0 &      bertbase &  original &   0.81752 &  0.78672 &   0.838363 &  0.811721 \\
# 0 &     bertlarge &     N\_all &   0.79648 &  0.73360 &   0.839129 &  0.782824 \\
# 0 &     bertlarge &     N\_pro &   0.77940 &  0.65984 &   0.867206 &  0.749443 \\
# 0 &     bertlarge &    N\_weat &   0.80264 &  0.73920 &   0.846619 &  0.789271 \\
# 0 &     bertlarge &   mix\_all &   0.79536 &  0.72332 &   0.845079 &  0.779473 \\
# 0 &     bertlarge &   mix\_pro &   0.79656 &  0.73784 &   0.836022 &  0.783869 \\
# 0 &     bertlarge &  mix\_weat &   0.78886 &  0.71024 &   0.842755 &  0.770844 \\
# 0 &     bertlarge &  original &   0.80456 &  0.78720 &   0.815515 &  0.801107 \\
# 0 &      distbase &     N\_all &   0.81732 &  0.78896 &   0.836401 &  0.811988 \\
# 0 &      distbase &     N\_pro &   0.81768 &  0.77960 &   0.843869 &  0.810462 \\
# 0 &      distbase &    N\_weat &   0.81948 &  0.78936 &   0.839959 &  0.813874 \\
# 0 &      distbase &   mix\_all &   0.82184 &  0.79472 &   0.840298 &  0.816874 \\
# 0 &      distbase &   mix\_pro &   0.82154 &  0.78364 &   0.847912 &  0.814510 \\
# 0 &      distbase &  mix\_weat &   0.82206 &  0.78328 &   0.849139 &  0.814881 \\
# 0 &      distbase &  original &   0.81176 &  0.77760 &   0.834621 &  0.805102 \\
# 0 &   robertabase &     N\_all &   0.82316 &  0.77008 &   0.861541 &  0.813247 \\
# 0 &   robertabase &     N\_pro &   0.81764 &  0.73288 &   0.882478 &  0.800752 \\
# 0 &   robertabase &    N\_weat &   0.81972 &  0.73928 &   0.881018 &  0.803950 \\
# 0 &   robertabase &   mix\_all &   0.83316 &  0.78040 &   0.872462 &  0.823867 \\
# 0 &   robertabase &   mix\_pro &   0.82324 &  0.76032 &   0.869772 &  0.811371 \\
# 0 &   robertabase &  mix\_weat &   0.83022 &  0.78056 &   0.866634 &  0.821348 \\
# 0 &   robertabase &  original &   0.81812 &  0.74376 &   0.873696 &  0.803509 \\
# 0 &  robertalarge &     N\_all &   0.81984 &  0.76528 &   0.859016 &  0.809443 \\
# 0 &  robertalarge &     N\_pro &   0.81812 &  0.75064 &   0.867752 &  0.804959 \\
# 0 &  robertalarge &    N\_weat &   0.81972 &  0.76096 &   0.862297 &  0.808465 \\
# 0 &  robertalarge &   mix\_all &   0.81456 &  0.74848 &   0.862463 &  0.801439 \\
# 0 &  robertalarge &   mix\_pro &   0.81410 &  0.72812 &   0.879330 &  0.796613 \\
# 0 &  robertalarge &  mix\_weat &   0.81620 &  0.76140 &   0.855121 &  0.805544 \\
# 0 &  robertalarge &  original &   0.81956 &  0.74824 &   0.872726 &  0.805703 \\
# \bottomrule
# \end{tabular}

# %%
acc_df_short
